# %% [markdown]
# # Questão 2

# %% [markdown]
# ## Importando Bibliotecas

# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Carregando Dados

# %%
produtos = pd.read_csv('../../datasets/produtos_raw.csv')

produtos.sample(10)
# Out:
#                                                   name         price  code  \
# 15                                   Sonda Garmin Axis   R$ 30005.99    16
# 54                 Motor de Popa Yamaha Evo Dash 155HP  R$ 121534.82    54
# 105                          Cabo de Nylon Bruce Nexus     R$ 832.02   102
# 128                                Corrente Delta Axis    R$ 3769.93   124
# 68           Motor de Popa Torqeedo Nautic Swift 223HP    R$ 25557.7    65
# 84   Motor Elétrico Torqeedo Barracuda Magnum Helix...  R$ 122148.49    81
# 95           Motor Elétrico Yamaha Nautic Kraken 133HP    R$ 88854.1    92
# 118         Cabo de Nylon Delta Force Magnum Leviathan     R$ 830.59   115
# 31                    Sonda AIS Impulse Oceanic Zenith   R$ 12502.46    32
# 85               Motor Elétrico Volvo Nautic Vox 118HP   R$ 51634.04    82
#
#        actual_category
# 15         eletrônicos
# 54          Propulssão
# 105          AnCoRaGeM
# 128          AncorageM
# 68           Propulção
# 84           Propulçao
# 95            Propução
# 118         Ancoraguem
# 31         ELETRONICOS
# 85   P R O P U L S Ã O

# %%
produtos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             157 non-null    object
#  1   price            157 non-null    object
#  2   code             157 non-null    int64
#  3   actual_category  157 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 5.0+ KB

# %% [markdown]
# ## Renomeando Colunas

# %% [markdown]
# As colunas `code` e `actual_category` serão renomeadas para garantir consistência e simplicidade.

# %%
produtos.rename(
    columns={
        'code': 'id',
        'actual_category': 'category'
    },
    inplace=True
)

produtos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      157 non-null    object
#  1   price     157 non-null    object
#  2   id        157 non-null    int64
#  3   category  157 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 5.0+ KB

# %% [markdown]
# ## Analisando Duplicatas

# %%
print(produtos.duplicated().sum())
# Out:
# 0

# %%
print(produtos.duplicated(subset='id').sum())
# Out:
# 7

# %%
print(produtos.duplicated(subset='name').sum())
# Out:
# 7

# %%
print(produtos.duplicated(subset='price').sum())
# Out:
# 7

# %%
produtos[produtos.duplicated(subset='price', keep=False)]
# Out:
#                                        name         price   id  \
# 36             GPS Lowrance Evo Storm Drift    R$ 6067.71   37
# 37             GPS Lowrance Evo Storm Drift    R$ 6067.71   37
# 62        Motor Diesel Yanmar Velocity 37HP  R$ 102221.97   62
# 63        Motor Diesel Yanmar Velocity 37HP  R$ 102221.97   62
# 64        Motor Diesel Yanmar Velocity 37HP  R$ 102221.97   62
# 65        Motor Diesel Yanmar Velocity 37HP  R$ 102221.97   62
# 124         Boia de Arqueamento Delta Nexus    R$ 4349.86  145
# 131  Cabo de Nylon Delta Velocity Core Mako    R$ 1549.35  127
# 132  Cabo de Nylon Delta Velocity Core Mako    R$ 1549.35  127
# 150         Boia de Arqueamento Delta Nexus    R$ 4349.86  145
# 151         Boia de Arqueamento Delta Nexus    R$ 4349.86  145
#
#                   category
# 36   E L E T R Ô N I C O S
# 37             ELEtRÔNICOS
# 62       P R O P U L S Ã O
# 63                Propução
# 64               propulsão
# 65                    Prop
# 124              AncorageM
# 131              Encoragem
# 132               Encoragi
# 150              AncorajeM
# 151              Ancoragen

# %% [markdown]
# Temos 7 produtos duplicados, com as colunas `name`, `price` e `id` iguais. Vamos removê-los.

# %%
produtos.drop_duplicates(
    subset='id',
    inplace=True
)

produtos.reset_index(
    drop=True,
    inplace=True
)

produtos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      150 non-null    object
#  1   price     150 non-null    object
#  2   id        150 non-null    int64
#  3   category  150 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 4.8+ KB

# %% [markdown]
# ## Padronizando Colunas

# %% [markdown]
# A coluna `price` não está com tipo numério e a coluna `category` possui formato fora de padrão. Vamos padronizar para poder normalizar os dados.

# %%
def fix_category(string: str) -> str:
    s = string.lower()
    if s.startswith('e'):
        return 'eletrônicos'
    if s.startswith('p'):
        return 'propulsão'
    if s.startswith('a'):
        return 'ancoragem'
    return ''

# %%
produtos['price'] = produtos['price'].apply(lambda x: x[3:]).astype('float')

produtos['category'] = produtos['category'].apply(fix_category)

produtos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      150 non-null    object
#  1   price     150 non-null    float64
#  2   id        150 non-null    int64
#  3   category  150 non-null    object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 4.8+ KB

# %% [markdown]
# ## Normalização

# %% [markdown]
# Vamos criar uma `DataFrame` com as categorias e deixar apenas uma id numérica com os produtos.

# %%
categories = pd.DataFrame(
    {
    'id': [1, 2, 3],
    'name': ['eletrônicos', 'propulsão', 'ancoragem']
    }
)

produtos = (
    produtos.
        merge(
            categories,
            left_on='category',
            right_on='name'
        ).drop(
            columns=['name_y', 'category']
        ).rename(
            columns={
                'name_x': 'name',
                'id_x': 'id',
                'id_y': 'category_id'
            }
        )
)

# %%
produtos.sample(5)
# Out:
#                                              name      price   id  category_id
# 113  Boia de Arqueamento Danforth Tidal Zen Swift     799.29  114            3
# 43                      GPS Simrad Zen Hydra Peak   10806.84   44            1
# 25       Piloto Automático Furuno Core Boost Flux   17283.18   26            1
# 81          Motor Elétrico Volvo Nautic Vox 118HP   51634.04   82            2
# 56       Motor de Popa Honda Vector Kinetic 174HP  118790.57   57            2

# %%
categories.head()
# Out:
#    id         name
# 0   1  eletrônicos
# 1   2    propulsão
# 2   3    ancoragem
